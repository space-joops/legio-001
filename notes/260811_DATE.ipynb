// %%
import { computeSundayMassBasis } from "../src/lib/monthlyReportUtils";

// %%
// 2026년 5월의 마지막 수요일은 5월 27일.
// 2026년 6월의 마지막 수요일은 6월 24일.
// 구간: 5월 28일 ~ 6월 24일.
// 이 구간 내의 주일(일요일): 5/31, 6/7, 6/14, 6/21 => 4번.
const result = computeSundayMassBasis("2026-06", 3, 5); // 5명 기준

// %%
result
// Out:
// {
//   from: 2026-05-28T00:00:00.000Z,
//   to: 2026-06-24T00:00:00.000Z,
//   sundayCount: 4,
//   peopleCount: 5,
//   total: 20
// }
